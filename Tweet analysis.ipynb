# %% [markdown]
# # Analyzing tweet content

# %% [markdown]
# # Import

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import numpy as np
import itertools
from collections import Counter
import warnings
import re
from IPython.display import clear_output
from IPython.core.display import display, HTML

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# # Data

# %%
AllTweets = pd.read_csv("Data/AllTweets.csv", index_col=0)

# %%
AllTweets.head()
# Out:
#    index              date  favorites  geo hashtags                      id  \
# 0      0  2020-03-02 00:59          1  NaN      NaN  1.2342670258093302e+18
# 1      1  2020-03-02 00:57        586  NaN      NaN  1.2342664682898268e+18
# 2      2  2020-03-02 00:56          0  NaN      NaN  1.2342662720635412e+18
# 3      3  2020-03-02 00:51          0  NaN  # # # #   1.234265145389527e+18
# 4      4  2020-03-02 00:51          0  NaN      NaN  1.2342650855996006e+18
#
#   mentions                                          permalink  retweets  \
# 0      NaN  https://twitter.com/kevindienda/status/1234267...         0
# 1        @  https://twitter.com/lewinskylou2/status/123426...       252
# 2      NaN  https://twitter.com/Watskeburtinmi1/status/123...         0
# 3        @  https://twitter.com/Gabber07/status/1234265145...         1
# 4        @  https://twitter.com/stellardoor24/status/12342...         0
#
#                                                 text  username
# 0  sommige van jullie willen interessant doen met...       NaN
# 1  Volgens minister Bruno Bruins (Medische Zorg) ...       NaN
# 2  Carnavalsstichting Tilburg schrikt van twee ni...       NaN
# 3  LIVE - Patiënte in Beatrixziekenhuis Gorinchem...       NaN
# 4  Coronavirus Cold Open - SNL https://youtu.be/H...       NaN

# %%
AllTweets.permalink.loc[4]
# Out:
# 'https://twitter.com/stellardoor24/status/1234265085599600641'

# %% [markdown]
# # Analysing news tweets

# %% [markdown]
# Removing news tweets to just showing people interacting instead of sharing news article

# %%
def RemoveNewsTweets(DataFrame):
    """
    Takes dataframe with tweets and returns the same dataframe without all the news tweets (removes every tweet with a link)
    """
    pattern = 'https:\/\/|http:\/\/'
    length = len(DataFrame)
    for n in range(length):
        clear_output(wait=True)
        result = re.search(pattern, AllTweets.text.loc[n])
        if result:
            DataFrame = DataFrame.drop(n)
        else:
            continue
        print("Current progress: "+ str(np.round(n/length*100,2)),"%")
    return DataFrame

# %%
# %time AllnonNewsTweets = RemoveNewsTweets(AllTweets)
# Out:
# Current progress: 100.0 %
# Wall time: 1h 20min 5s

# %%
AllnonNewsTweets
# Out:
#         index              date  favorites  geo hashtags  \
# 0           0  2020-03-02 00:59          1  NaN      NaN
# 6           6  2020-03-02 00:49          0  NaN      NaN
# 8           8  2020-03-02 00:46          0  NaN      NaN
# 9           9  2020-03-02 00:45          0  NaN      # #
# 10         10  2020-03-02 00:45          0  NaN      NaN
# ...       ...               ...        ...  ...      ...
# 165252   3563  2020-02-29 01:12         20  NaN      # #
# 165254   3565  2020-02-29 01:05          0  NaN        #
# 165256   3567  2020-02-29 01:02          0  NaN      # #
# 165257   3568  2020-02-29 01:02          1  NaN      NaN
# 165259   3570  2020-02-29 01:01          2  NaN      NaN
#
#                             id mentions  \
# 0       1.2342670258093302e+18      NaN
# 6       1.2342644252275302e+18        @
# 8        1.234263841913086e+18      NaN
# 9       1.2342635473345495e+18      NaN
# 10      1.2342635292990874e+18      NaN
# ...                        ...      ...
# 165252  1.2335455419733975e+18      NaN
# 165254  1.2335437430154732e+18      NaN
# 165256  1.2335431368839373e+18      NaN
# 165257   1.233543045389353e+18      NaN
# 165259   1.233542879890436e+18      NaN
#
#                                                 permalink  retweets  \
# 0       https://twitter.com/kevindienda/status/1234267...         0
# 6       https://twitter.com/Aislin37081715/status/1234...         0
# 8       https://twitter.com/ElPee39284996/status/12342...         0
# 9       https://twitter.com/MariaVANL/status/123426354...         0
# 10      https://twitter.com/APooh2310/status/123426352...         0
# ...                                                   ...       ...
# 165252  https://twitter.com/piep_kuiken/status/1233545...         6
# 165254  https://twitter.com/LeavingHolland/status/1233...         0
# 165256  https://twitter.com/gewoonmens/status/12335431...         1
# 165257  https://twitter.com/LavendelSnuiver/status/123...         0
# 165259  https://twitter.com/jorinl/status/123354287989...         1
#
#                                                      text  username
# 0       sommige van jullie willen interessant doen met...       NaN
# 6       De likes vind ik net zo walgelijk als de tweet...       NaN
# 8       De inwoners van Lesbos zien de migranten als e...       NaN
# 9       # marcvanranst doet die trui niet meer uit tot...       NaN
# 10      1. Afgezien daarvan; de EU (en aangesloten lan...       NaN
# ...                                                   ...       ...
# 165252  Journalist tegen bejaarde mevrouw: ‘Is # coron...       NaN
# 165254  Stel je wordt nu griepig. T is er de tijd van ...       NaN
# 165256  Morgen maar even bellen met de ggd. Die lui di...       NaN
# 165257  De mutatie van de mens als gevolg van het coro...       NaN
# 165259  Daarbij is het Coronavirus geen onschuldig gri...       NaN
#
# [70962 rows x 11 columns]

# %% [markdown]
# #### Save as .csv

# %%
AllnonNewsTweets.to_csv("Data/AllnonLinkTweets.csv")

# %% [markdown]
# ### Get all Urls in twitter links

# %%
def GetAllLinksIntweets(DataFrame):
    """
    Takes dataframe with tweets and returns the same dataframe without all the news tweets (removes every tweet with a link)
    """
    pattern = '(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,})'
    length = len(DataFrame)
    UrlList = []
    for n in range(length):
        clear_output(wait=True)
        result = re.search(pattern, AllTweets.text.loc[n])
        if result:
            UrlList.append(result.group())
        else:
            continue
        print("Current progress: "+ str(np.round(n/length*100,2)),"%")
    return UrlList

# %%
# %time AllUrlsInTweets = GetAllLinksIntweets(AllTweets)
# Out:
# Current progress: 99.73 %

# %%
Counter(AllUrlsInTweets).most_common(10)
# Out:
# [('https://youtu.be/H4qvO0StKto', 242),
#  ('https://www.rtlnieuws.nl/nieuws/nederland/artikel/5056536/sehraz-breda-coronavirus-16-intensive-care-besmet-covid19',
#   224),
#  ('http://AD.nl', 214),
#  ('https://youtu.be/XezLiezWN0E', 185),
#  ('http://NU.nl', 167),
#  ('https://nos.nl/l/2327194', 151),
#  ('https://www.rtlnieuws.nl/nieuws/nederland/artikel/5056941/ggd-chef-al-6000-mensen-besmet-met-coronaviurs',
#   144),
#  ('http://cutt.ly/8e5346v', 137),
#  ('https://www.rivm.nl/nieuws/actuele-informatie-over-coronavirus', 118),
#  ('http://Rijksoverheid.nl', 109)]

# %% [markdown]
# ### Get all domain an their appearance

# %%
PreFixes = []
pattern = 'http(?:s)?:\/\/(?:[\w-]+\.)*([\w-]{1,63})(?:\.(?:\w{3}|\w{2}))(?:$|\/)'
for x in AllUrlsInTweets:
    result = re.search(pattern, x)
    if result:
        PreFixes.append(result.group())

# %%
Counter(PreFixes).most_common(1000)
# Out:
# [('https://twitter.com/', 13176),
#  ('http://dlvr.it/', 4826),
#  ('http://bit.ly/', 4129),
#  ('https://www.telegraaf.nl/', 3643),
#  ('https://www.ad.nl/', 2207),
#  ('https://www.nu.nl/', 2113),
#  ('https://nos.nl/', 2027),
#  ('https://nieuwsblik.nl/', 1940),
#  ('https://youtu.be/', 1879),
#  ('https://buff.ly/', 1565),
#  ('https://ift.tt/', 1544),
#  ('https://watskeburtinmijnstraat.nl/', 1375),
#  ('https://www.hln.be/', 1332),
#  ('https://www.rtlnieuws.nl/', 1257),
#  ('https://bit.ly/', 952),
#  ('http://zpr.io/', 892),
#  ('https://www.instagram.com/', 765),
#  ('https://goo.gl/', 754),
#  ('https://www.volkskrant.nl/', 743),
#  ('https://vrtnws.be/', 644),
#  ('http://a.msn.com/', 635),
#  ('https://www.nrc.nl/', 551),
#  ('https://www.parool.nl/', 531),
#  ('http://twib.in/', 495),
#  ('https://www.nos.nl/', 494),
#  ('https://brabantn.ws/', 476),
#  ('http://enz.nl/', 467),
#  ('http://ow.ly/', 458),
#  ('https://lnkd.in/', 422),
#  ('https://www.gelderlander.nl/', 379),
#  ('https://www.youtube.com/', 356),
#  ('https://www.rivm.nl/', 334),
#  ('https://www.dagelijksestandaard.nl/', 332),
#  ('http://feed.omroepbrabant.nl/', 328),
#  ('https://www.dvhn.nl/', 309),
#  ('https://www.trouw.nl/', 292),
#  ('https://www.nieuwsblad.be/', 292),
#  ('https://www.demorgen.be/', 275),
#  ('https://www.destentor.nl/', 272),
#  ('https://www.facebook.com/', 266),
#  ('https://tpo.nl/', 256),
#  ('https://www.bd.nl/', 250),
#  ('https://www.hartvannederland.nl/', 242),
#  ('http://www.msn.com/', 241),
#  ('https://fd.nl/', 232),
#  ('https://www.rijksoverheid.nl/', 223),
#  ('http://AD.nl', 214),
#  ('https://www.transport-online.nl/', 214),
#  ('https://www.rtlz.nl/', 206),
#  ('https://www.standaard.be/', 197),
#  ('http://startm.nl/', 192),
#  ('https://indignatie.nl/', 188),
#  ('https://www.bnr.nl/', 185),
#  ('https://www.knack.be/', 180),
#  ('https://m.nieuwsblad.be/', 174),
#  ('https://owst.nl/', 172),
#  ('https://www.1limburg.nl/', 172),
#  ('http://NU.nl', 167),
#  ('https://www.nporadio1.nl/', 164),
#  ('https://mailchi.mp/', 162),
#  ('https://indebuurt.nl/', 159),
#  ('https://rtvn.gr/', 157),
#  ('https://www.ed.nl/', 153),
#  ('http://tinyurl.com/', 151),
#  ('https://www.lc.nl/', 150),
#  ('https://www.rtvnoord.nl/', 148),
#  ('https://secure.avaaz.org/', 148),
#  ('https://www.ninefornews.nl/', 144),
#  ('https://tinyurl.com/', 143),
#  ('http://chng.it/', 142),
#  ('https://www.linkedin.com/', 142),
#  ('https://www.limburger.nl/', 139),
#  ('https://rtvr.nl/', 139),
#  ('https://nieuwspaal.nl/', 137),
#  ('https://sporza.be/', 137),
#  ('http://cutt.ly/', 137),
#  ('https://www.tubantia.nl/', 136),
#  ('https://www.stadindex.nl/', 128),
#  ('https://www.gpfans.com/', 127),
#  ('https://www.businessinsider.nl/', 127),
#  ('https://www.nhnieuws.nl/', 127),
#  ('https://www.bndestem.nl/', 126),
#  ('https://www.hpdetijd.nl/', 124),
#  ('https://www.fcupdate.nl/', 122),
#  ('https://twitter.nu123.nl/', 116),
#  ('https://opgelicht.avrotros.nl/', 116),
#  ('https://eenvandaag.avrotros.nl/', 113),
#  ('https://www.joods.nl/', 113),
#  ('http://Rijksoverheid.nl', 109),
#  ('https://www.geenstijl.nl/', 109),
#  ('https://rtvd.nl/', 107),
#  ('https://wnl.tv/', 107),
#  ('https://www.vrt.be/', 106),
#  ('https://www.rijnmond.nl/', 105),
#  ('https://is.gd/', 105),
#  ('https://www.netwerk24.com/', 105),
#  ('https://www.welingelichtekringen.nl/', 103),
#  ('https://wp.me/', 102),
#  ('http://www.1limburg.nl/', 102),
#  ('http://www.soccernews.nl/', 102),
#  ('https://www.nd.nl/', 102),
#  ('https://www.iex.nl/', 102),
#  ('https://gld.nl/', 101),
#  ('https://www.rd.nl/', 100),
#  ('https://www.tijd.be/', 99),
#  ('https://www.omroepwest.nl/', 99),
#  ('https://sportnieuws.nl/', 99),
#  ('https://www.omroepbrabant.nl/', 98),
#  ('https://go.njws.nl/', 97),
#  ('https://www.bruzz.be/', 95),
#  ('https://www.timesofisrael.com/', 95),
#  ('https://www.washingtonpost.com/', 93),
#  ('https://www.at5.nl/', 93),
#  ('https://f7td5.app.goo.gl/', 92),
#  ('https://www.gva.be/', 91),
#  ('https://www.theguardian.com/', 89),
#  ('http://www.internetbode.nl/', 89),
#  ('https://www.nationalezorggids.nl/', 88),
#  ('http://www.siris.nl/', 88),
#  ('https://www.metronieuws.nl/', 87),
#  ('https://www.omroepflevoland.nl/', 83),
#  ('https://medium.com/', 83),
#  ('https://ad.nl/', 81),
#  ('https://jdreport.com/', 81),
#  ('https://www.denederlandsevereniging.nl/', 79),
#  ('http://nos.nl/', 79),
#  ('https://dutchcryptotalk.com/', 78),
#  ('https://gisanddata.maps.arcgis.com/', 78),
#  ('http://vlaamsemedia.trendolizer.com/', 78),
#  ('https://dailygp.com/', 76),
#  ('https://www.indeleiderstrui.nl/', 76),
#  ('http://Telegraaf.nl', 75),
#  ('http://www.kliknieuws.nl/', 75),
#  ('https://www.rtvoost.nl/', 74),
#  ('https://grootheerenveen.nl/', 74),
#  ('https://www.rtvutrecht.nl/', 73),
#  ('https://www.irishtimes.com/', 73),
#  ('https://www.travelpro.nl/', 72),
#  ('http://www.dezorgsector.eu/', 70),
#  ('https://omrop.fr/', 70),
#  ('https://ejbron.wordpress.com/', 70),
#  ('https://www.nederlandwereldwijd.nl/', 68),
#  ('http://j.mp/', 67),
#  ('https://link.medium.com/', 66),
#  ('https://sceptr.net/', 65),
#  ('https://www.noordhollandsdagblad.nl/', 64),
#  ('https://biflatie.nl/', 64),
#  ('https://zorgnu.avrotros.nl/', 64),
#  ('https://speld.nl/', 63),
#  ('https://m.hln.be/', 63),
#  ('https://op.nu.nl/', 63),
#  ('https://www.spanjevandaag.com/', 62),
#  ('http://www.hetkontakt.nl/', 62),
#  ('https://www.nieuwskoerier.nl/', 61),
#  ('https://m.facebook.com/', 60),
#  ('https://www.f1maximaal.nl/', 60),
#  ('https://rtvoo.st/', 60),
#  ('https://www.healthbuzz.be/', 59),
#  ('https://nu123.nl/', 59),
#  ('https://www.info-coronavirus.be/', 58),
#  ('https://app.1848.nl/', 58),
#  ('https://www.studioalphen.nl/', 58),
#  ('https://rtvu.nl/', 58),
#  ('https://www.thuisarts.nl/', 57),
#  ('https://www.tweedekamer.nl/', 57),
#  ('https://www.pzc.nl/', 56),
#  ('https://www.bbc.com/', 55),
#  ('https://www.omroepgelderland.nl/', 54),
#  ('https://open.spotify.com/', 54),
#  ('https://trouw.nl/', 53),
#  ('https://dagblad070.nl/', 52),
#  ('https://www.voetbalkrant.com/', 52),
#  ('http://www.voetbalnieuws.be/', 52),
#  ('https://dagblad010.nl/', 51),
#  ('https://wapo.st/', 51),
#  ('https://shar.es/', 50),
#  ('https://www.jpost.com/', 50),
#  ('https://www.rtvdrenthe.nl/', 48),
#  ('https://www.npostart.nl/', 48),
#  ('https://www.martinvrijland.nl/', 48),
#  ('https://www.meerovermedisch.nl/', 48),
#  ('https://www.pscp.tv/', 48),
#  ('https://nukta360.com/', 47),
#  ('http://goudportal.nl/', 47),
#  ('https://tpook.nl/', 47),
#  ('https://lgld.nl/', 47),
#  ('https://www.vtbl.nl/', 46),
#  ('https://www.medischcontact.nl/', 46),
#  ('https://dtvnieuws.nl/', 46),
#  ('https://www.vi.nl/', 46),
#  ('https://goudsdagblad.nl/', 45),
#  ('https://capelsdagblad.nl/', 45),
#  ('https://www.nationaleonderwijsgids.nl/', 45),
#  ('http://edjesvlog.com/', 45),
#  ('https://brabosh.com/', 44),
#  ('http://coronanieuws.be', 44),
#  ('https://www.repubblica.it/', 43),
#  ('https://barendrechtsdagblad.nl/', 43),
#  ('https://www.oogtv.nl/', 43),
#  ('https://www.omroepzeeland.nl/', 42),
#  ('https://studio040.nl/', 42),
#  ('https://abnamro.smh.re/', 42),
#  ('https://nl.motorsport.com/', 41),
#  ('https://www.corriere.it/', 41),
#  ('https://eunmask.wordpress.com/', 41),
#  ('https://www.hbvl.be/', 41),
#  ('https://www.digitaalburg.com/', 40),
#  ('https://voorburgsdagblad.nl/', 39),
#  ('https://m.youtube.com/', 39),
#  ('http://ad.nl/', 38),
#  ('https://go.schorel.eu/', 38),
#  ('https://r.providerlijst.nl/', 38),
#  ('https://www.stopdebankiers.com/', 38),
#  ('https://www.bnnvara.nl/', 38),
#  ('https://www.ringtv.be/', 38),
#  ('https://www.ongehoordnederland.nl/', 38),
#  ('https://kw.be/', 38),
#  ('http://rendement.nl/', 38),
#  ('https://www.google.com/', 37),
#  ('https://www.nytimes.com/', 37),
#  ('https://hubs.ly/', 37),
#  ('https://www.arcgis.com/', 37),
#  ('https://localfocus2.appspot.com/', 36),
#  ('https://www.arenalokaal.nl/', 36),
#  ('https://www.nationalgeographic.nl/', 36),
#  ('https://www.voetbalbelgie.be/', 36),
#  ('http://andijkernieuws.net/', 36),
#  ('https://www.cnbc.com/', 34),
#  ('https://www.msn.com/', 34),
#  ('https://www.quotenet.nl/', 34),
#  ('https://www.eoswetenschap.eu/', 34),
#  ('https://www.omropfryslan.nl/', 34),
#  ('https://reactnieuws.net/', 34),
#  ('https://www.bright.nl/', 33),
#  ('http://www.f1journaal.be/', 33),
#  ('https://www.bbc.co.uk/', 33),
#  ('https://www.zerohedge.com/', 33),
#  ('https://amp.nos.nl/', 33),
#  ('https://www.scientias.nl/', 33),
#  ('https://www.unity.nu/', 33),
#  ('https://www.rechtspraak.nl/', 33),
#  ('http://rijksoverheid.nl/', 33),
#  ('https://radar.avrotros.nl/', 33),
#  ('https://dutchcloudmagazine.nl/', 32),
#  ('https://www.veronicainside.nl/', 32),
#  ('https://www.hardloopnieuws.nl/', 32),
#  ('http://www.rivm.nl/', 32),
#  ('https://www.wyniasweek.nl/', 32),
#  ('https://www.who.int/', 31),
#  ('https://www.duurzaamnieuws.nl/', 31),
#  ('https://www.ggdrotterdamrijnmond.nl/', 31),
#  ('https://www.tvgids.nl/', 31),
#  ('https://l1.nl/', 30),
#  ('https://www.belegger.nl/', 30),
#  ('http://www.rijksoverheid.nl/', 30),
#  ('https://www.waterkant.net/', 30),
#  ('https://www.artsenzondergrenzen.nl/', 30),
#  ('https://nyti.ms/', 29),
#  ('https://motorsportz.nl/', 29),
#  ('https://www.protestantsekerk.nl/', 29),
#  ('https://mol.im/', 29),
#  ('http://www.headlines.nl/', 29),
#  ('https://www.formule1.nl/', 29),
#  ('https://www.looopings.nl/', 29),
#  ('http://snwchmps.nl/', 29),
#  ('https://showbizznetwork.nl/', 29),
#  ('https://schiedamvandaag.nl/', 28),
#  ('https://cip.nl/', 28),
#  ('https://www.nieuweoogst.nl/', 28),
#  ('https://www.zorgkrant.nl/', 28),
#  ('https://landenkompas.nl/', 28),
#  ('https://helmond.ditisonzewijk.nl/', 28),
#  ('https://frieschdagblad.nl/', 27),
#  ('https://www.reuters.com/', 27),
#  ('https://www.dailymail.co.uk/', 27),
#  ('https://www.voetbalzone.nl/', 27),
#  ('https://nieuws.ondh.nl/', 27),
#  ('https://nl.wikipedia.org/', 27),
#  ('https://www.nationaletransportgids.nl/', 27),
#  ('https://www.scmp.com/', 27),
#  ('http://Www.nos.nl', 27),
#  ('http://www.nos.nl', 27),
#  ('https://jouwstad.eu/', 27),
#  ('https://www.gpupdate.net/', 26),
#  ('https://www.worldunity.me/', 26),
#  ('https://www.want.nl/', 26),
#  ('https://denhaagfm.nl/', 26),
#  ('https://flutrackers.com/', 25),
#  ('https://detheorist.nl/', 25),
#  ('https://m.gva.be/', 25),
#  ('https://doorbraak.be/', 25),
#  ('http://rd.nl/', 25),
#  ('https://rabobank.smh.re/', 25),
#  ('https://threadreaderapp.com/', 25),
#  ('https://kvk.smh.re/', 25),
#  ('https://www.evofenedex.nl/', 25),
#  ('https://www.turksvoetbal.net/', 25),
#  ('https://www.politie.nl/', 25),
#  ('http://Hartvannederland.nl', 24),
#  ('https://www.ggdgv.nl/', 24),
#  ('https://zeewolde-actueel.nl/', 24),
#  ('http://www.viln.nl/', 24),
#  ('https://blendle.com/', 24),
#  ('http://www.info-coronavirus.be', 24),
#  ('https://www.kliknieuws.nl/', 24),
#  ('https://www.bloomberg.com/', 24),
#  ('https://www.telegraph.co.uk/', 24),
#  ('https://www.westerwoldeactueel.nl/', 24),
#  ('https://www.gelrenieuws.nl/', 24),
#  ('http://destentor.nl', 23),
#  ('https://nmky.be/', 23),
#  ('https://www.srnieuws.com/', 23),
#  ('https://www.geotrendlines.nl/', 23),
#  ('https://www.europa-nu.nl/', 23),
#  ('http://www.rivm.nl', 23),
#  ('http://nieuwsonderwijsnederland.nl/', 23),
#  ('https://neusjes.net/', 23),
#  ('https://www.pharos.nl/', 22),
#  ('https://fakka.nl/', 22),
#  ('https://www.cnn.com/', 22),
#  ('https://voetbalflitsen.nl/', 22),
#  ('https://www.riskenbusiness.nl/', 22),
#  ('https://www.upinthesky.nl/', 22),
#  ('https://www.lokaleomroepmill.nl/', 22),
#  ('http://WijchensNieuws.nl', 22),
#  ('https://sittard-geleen.nieuws.nl/', 22),
#  ('http://Bol.com', 21),
#  ('http://disq.us/', 21),
#  ('https://joop.bnnvara.nl/', 21),
#  ('https://www.topics.nl/', 21),
#  ('https://www.duic.nl/', 21),
#  ('https://www.voka.be/', 21),
#  ('https://www.ft.com/', 21),
#  ('https://onsalmere.nl/', 21),
#  ('https://www.fnv.nl/', 21),
#  ('https://plaatjes-spreuken-quotes-memes.blogspot.com/', 21),
#  ('https://www.deondernemer.nl/', 20),
#  ('https://onsgooi.nl/', 20),
#  ('https://cards.twitter.com/', 20),
#  ('http://s.w0w.eu/', 20),
#  ('http://fok.nl/', 20),
#  ('https://www.nederweert24.nl/', 20),
#  ('https://anderlechtrss.be/', 20),
#  ('https://snip.ly/', 20),
#  ('https://www.cyclokalender.nl/', 19),
#  ('https://www.vice.com/', 19),
#  ('https://www.welt.de/', 19),
#  ('https://www.getrevue.co/', 19),
#  ('https://www.nieuwsgrazer.nl/', 19),
#  ('https://www.dejongeturken.com/', 19),
#  ('https://www.adformatie.nl/', 19),
#  ('https://fm.bnr.nl/', 19),
#  ('https://deazijnpisser.blogspot.com/', 19),
#  ('https://www.villamedia.nl/', 19),
#  ('https://www.boerenbusiness.nl/', 19),
#  ('http://wmr.nu/', 19),
#  ('https://www.kn.nl/', 19),
#  ('https://dartsnieuws.com/', 19),
#  ('https://www.rodekruis.nl/', 19),
#  ('https://aagentrss.be/', 19),
#  ('https://omroepvenlo.nl/', 19),
#  ('https://www.plusonline.nl/', 19),
#  ('https://rtvapd.nl/', 19),
#  ('http://va.newsrepublic.net/', 18),
#  ('https://onderwijs.vlaanderen.be/', 18),
#  ('http://brabosh.com/', 18),
#  ('https://www.test-aankoop.be/', 18),
#  ('https://servicemanagement.nl/', 18),
#  ('https://www.weblogzwolle.nl/', 18),
#  ('https://edition.cnn.com/', 18),
#  ('https://nypost.com/', 18),
#  ('http://verenoflood.nu/', 18),
#  ('https://krcgenkrss.be/', 18),
#  ('https://sportingroningen.nl/', 18),
#  ('https://pastebin.com/', 17),
#  ('http://oldebroek.net/', 17),
#  ('http://www.dumpert.nl/', 17),
#  ('https://www.nieuwwij.nl/', 17),
#  ('https://www.flaironline.nl/', 17),
#  ('https://petities.nl/', 17),
#  ('https://www.medemblikactueel.nl/', 17),
#  ('https://www.wielerkrant.be/', 17),
#  ('https://www.mkb.nl/', 17),
#  ('https://www.westlanders.nu/', 17),
#  ('https://www.vosabb.nl/', 17),
#  ('https://www.haaretz.com/', 17),
#  ('https://www.rtlboulevard.nl/', 17),
#  ('https://grootdefryskemarren.nl/', 17),
#  ('https://www.cdc.gov/', 17),
#  ('https://ons-lelystad.nl/', 17),
#  ('https://roermond.nieuws.nl/', 17),
#  ('https://okt.to/', 17),
#  ('https://soundcloud.com/', 17),
#  ('https://tvvisie.be/', 17),
#  ('https://www.knvb.nl/', 17),
#  ('https://tvvalkenburg.tv/', 17),
#  ('http://be-alert.be', 17),
#  ('https://nederlandactueel.nl/', 16),
#  ('https://ultroniq.nl/', 16),
#  ('https://pnws.be/', 16),
#  ('https://www.verzekeraars.nl/', 16),
#  ('https://www.focus-wtv.be/', 16),
#  ('https://trends.knack.be/', 16),
#  ('https://www.hetkontakt.nl/', 16),
#  ('https://www.ukrant.nl/', 16),
#  ('https://rvo.smh.re/', 16),
#  ('https://nl.m.wikipedia.org/', 16),
#  ('https://dagelijksvanalles.be/', 16),
#  ('https://www.esportsclub.nl/', 16),
#  ('https://vertigoweb.be/', 16),
#  ('https://www.ing.nl/', 16),
#  ('https://www.uu.nl/', 16),
#  ('https://www.nationalerecreatiegids.nl/', 16),
#  ('https://www.voetbalprimeur.nl/', 16),
#  ('http://gelderlander.nl', 16),
#  ('https://www.theatlantic.com/', 16),
#  ('http://Voetbal24.be', 16),
#  ('https://www.oato.nl/', 16),
#  ('https://www.hollandskroonactueel.nl/', 16),
#  ('https://ozld.nl/', 16),
#  ('https://www.erasmusmagazine.nl/', 16),
#  ('https://www.oostende.be/', 16),
#  ('https://newscientist.nl/', 15),
#  ('https://www.radioafm.nl/', 15),
#  ('https://racingnews365.nl/', 15),
#  ('https://images.app.goo.gl/', 15),
#  ('https://news.sky.com/', 15),
#  ('https://nieuws.nl/', 15),
#  ('http://youtu.be/', 15),
#  ('https://www.medi-sfeer.be/', 15),
#  ('https://www.agf.nl/', 15),
#  ('https://www.bolero.be/', 15),
#  ('http://dagelijksvanalles.be/', 15),
#  ('https://vl-nieuws.nl/', 15),
#  ('http://op1npo.nl', 15),
#  ('https://www.ndr.de/', 15),
#  ('https://coronavirus.nl/', 15),
#  ('https://www.sprout.nl/', 15),
#  ('https://www.independent.co.uk/', 15),
#  ('https://www.landenkompas.nl/', 15),
#  ('https://apnews.com/', 15),
#  ('http://Parool.nl', 15),
#  ('https://sportinnederland.com/', 15),
#  ('https://pointer.kro-ncrv.nl/', 15),
#  ('https://www.hvzeeland.nl/', 15),
#  ('https://deschiedammeronline.nl/', 15),
#  ('https://www.ditisroden.nl/', 15),
#  ('https://decorrespondent.nl/', 15),
#  ('https://www.reddit.com/', 14),
#  ('https://www.altenatv.nl/', 14),
#  ('https://www.google.nl/', 14),
#  ('https://www.oldambtnu.nl/', 14),
#  ('https://www.spiegel.de/', 14),
#  ('http://Nu.nl', 14),
#  ('http://info-coronavirus.be', 14),
#  ('https://www.haarlemsdagblad.nl/', 14),
#  ('https://koerdischnieuws.nl/', 14),
#  ('https://www.nijkerkerveen.org/', 14),
#  ('https://universonline.nl/', 14),
#  ('http://www.bussumsnieuws.nl/', 14),
#  ('http://hospitality-management.nl/', 14),
#  ('https://www.berkelland.net/', 14),
#  ('https://www.gondola.be/', 14),
#  ('https://nl.metrotime.be/', 14),
#  ('http://www.zutphennieuws.nl/', 14),
#  ('https://www.margriet.nl/', 14),
#  ('https://www.haarlemupdates.nl/', 14),
#  ('https://www.taxipro.nl/', 14),
#  ('https://radio1.be/', 14),
#  ('https://schoonmaakjournaal.nl/', 14),
#  ('https://www.foxsports.nl/', 14),
#  ('https://www.persregiodender.be/', 14),
#  ('https://www.story.nl/', 14),
#  ('https://www.xgn.nl/', 14),
#  ('https://nl.motocrossmag.be/', 14),
#  ('https://www.grootsneek.nl/', 14),
#  ('https://portal.prpro.be/', 14),
#  ('https://mnlx.nl/', 14),
#  ('https://www.dodelijkeleugens.nl/', 13),
#  ('https://podcasts.apple.com/', 13),
#  ('https://bnonews.com/', 13),
#  ('https://crime-nieuws.nl/', 13),
#  ('https://www.medrxiv.org/', 13),
#  ('https://www.vno-ncw.nl/', 13),
#  ('https://www.xandernieuws.net/', 13),
#  ('https://112vdg.nl/', 13),
#  ('https://sportmagazine.knack.be/', 13),
#  ('http://nu.nl', 13),
#  ('https://haarlem105.nl/', 13),
#  ('https://en.wikipedia.org/', 13),
#  ('https://facto.nl/', 13),
#  ('https://waalwijk.nieuws.nl/', 13),
#  ('https://www.hoekschnieuws.nl/', 13),
#  ('https://reut.rs/', 13),
#  ('http://bol.com', 13),
#  ('https://www.zo-nws.nl/', 13),
#  ('http://ed.nl', 13),
#  ('https://www.onderwijsland.com/', 13),
#  ('https://www.utoday.nl/', 13),
#  ('https://luchtvaartnieuws.nl/', 13),
#  ('https://executivefinance.nl/', 13),
#  ('https://www.deonderwijssector.eu/', 13),
#  ('https://020amstelveen.nl/', 13),
#  ('https://schie.nu/', 13),
#  ('http://fd.nl/', 13),
#  ('https://solarmagazine.nl/', 13),
#  ('http://youtube.com/', 13),
#  ('http://bitcoinencryptocurrency.nl/', 13),
#  ('https://www.newslocker.com/', 13),
#  ('https://www.rtvridderkerk.nl/', 13),
#  ('http://Formule1.nl', 13),
#  ('https://kvmechelenrss.be/', 13),
#  ('https://www.blikopnieuws.nl/', 13),
#  ('http://bd.nl', 13),
#  ('http://niburu.co/', 13),
#  ('https://www.tvschijndel.nl/', 13),
#  ('https://rijksoverheid.nl/', 13),
#  ('http://Pastebin.com', 12),
#  ('https://mediatv.nl/', 12),
#  ('https://www.ynetnews.com/', 12),
#  ('https://m.standaard.be/', 12),
#  ('https://www.bild.de/', 12),
#  ('https://www.groene.nl/', 12),
#  ('https://telegraaf.nl/', 12),
#  ('https://www.078.nu/', 12),
#  ('https://flip.it/', 12),
#  ('https://www.overhetcoronavirus.nl/', 12),
#  ('https://www.kerknet.be/', 12),
#  ('http://www.gooieneembode.nl/', 12),
#  ('https://epidemio.wiv-isp.be/', 12),
#  ('https://sluitscholen.petities.nl', 12),
#  ('https://www.televizier.nl/', 12),
#  ('https://www.ellaster.nl/', 12),
#  ('https://israelcnn.com/', 12),
#  ('http://www.geenstijl.nl/', 12),
#  ('http://www.mooilaarbeek.nl/', 12),
#  ('https://johanschrijft.be/', 12),
#  ('http://www.brielsnieuwsland.nl/', 12),
#  ('https://heusden.nieuws.nl/', 12),
#  ('https://ggd.groningen.nl/', 12),
#  ('https://www.techzine.nl/', 12),
#  ('https://go.shr.lc/', 12),
#  ('https://thehill.com/', 12),
#  ('http://destadskoerier.nl/', 12),
#  ('https://www.alblasserdamsnieuws.nl/', 12),
#  ('https://video.repubblica.it/', 12),
#  ('http://Booking.com', 12),
#  ('https://www.dutchcowboys.nl/', 11),
#  ('https://noordernieuws.nl/', 11),
#  ('https://www.dotcomnieuws.com/', 11),
#  ('https://www.rkkerk.nl/', 11),
#  ('https://www.ncbi.nlm.nih.gov/', 11),
#  ('https://3voor12.vpro.nl/', 11),
#  ('https://www.amsterdam.nl/', 11),
#  ('http://www.nieuwsbladvoorhuizen.nl/', 11),
#  ('https://www.kinderopvangtotaal.nl/', 11),
#  ('https://www.foodpro-network.nl/', 11),
#  ('https://www.onemorething.nl/', 11),
#  ('http://zc.vg/', 11),
#  ('https://www.thelancet.com/', 11),
#  ('https://nieuwsgorkum.nl', 11),
#  ('https://www.boerderij.nl/', 11),
#  ('http://www.sport-planet.eu/', 11),
#  ('https://www.travmagazine.nl/', 11),
#  ('https://insights.abnamro.nl/', 11),
#  ('https://hvana.nl/', 11),
#  ('https://www.wielerflits.nl/', 11),
#  ('https://cleantotaal.nl/', 11),
#  ('http://www.bredavandaag.nl/', 11),
#  ('https://24live.co/', 11),
#  ('https://www.hortipoint.nl/', 11),
#  ('https://innovationorigins.com/', 11),
#  ('https://nudrenthe.nl/', 11),
#  ('http://www.weekbladwestvoorne.nl/', 11),
#  ('https://www.agconnect.nl/', 11),
#  ('https://www.rt.com/', 11),
#  ('https://045online.nl/', 11),
#  ('https://royalantwerprss.be/', 11),
#  ('https://www.skipr.nl/', 11),
#  ('https://www.appletips.nl/', 11),
#  ('https://twitch.tv/', 11),
#  ('https://www.libelle.nl/', 11),
#  ('http://MXO.nl', 11),
#  ('https://weblog-staphorst.nl/', 11),
#  ('https://ronvmedia.nl/', 11),
#  ('https://docs.google.com/', 11),
#  ('https://magilando.wordpress.com/', 10),
#  ('https://www.werkendam.net/', 10),
#  ('https://dealphenaar.net/', 10),
#  ('https://radio2.be/', 10),
#  ('https://www.112-ov.nl/', 10),
#  ('https://www.altena-regionieuws.nl/', 10),
#  ('https://www.genderen.org/', 10),
#  ('https://www.allesoverhr.nl/', 10),
#  ('http://www.info-coronavirus.be/', 10),
#  ('https://www.wijlimburg.nl/', 10),
#  ('http://www.laardercourant.nl/', 10),
#  ('https://datanews.knack.be/', 10),
#  ('https://businessam.be/', 10),
#  ('https://oal.lu/', 10),
#  ('https://www.delta.tudelft.nl/', 10),
#  ('https://vremdemirror.com/', 10),
#  ('https://external-preview.redd.it/', 10),
#  ('https://www.pvda.be/', 10),
#  ('http://Thuisarts.nl', 10),
#  ('https://www.hetacv.be/', 10),
#  ('https://www.hardnieuws.nl/', 10),
#  ('https://www.rtl.lu/', 10),
#  ('https://limburg24.nl/', 10),
#  ('https://meijel24.nl/', 10),
#  ('https://www.advocatie.nl/', 10),
#  ('http://www.groothellevoet.nl/', 10),
#  ('http://rivm.nl', 10),
#  ('https://www.nbcnews.com/', 10),
#  ('https://www.folia.nl/', 10),
#  ('https://www.foodagribusiness.nl/', 10),
#  ('https://clubbruggerss.be/', 10),
#  ('https://rodekru.is/', 10),
#  ('https://www.luchtvaartnieuws.nl/', 10),
#  ('https://www.ngf.nl/', 10),
#  ('https://pwc.smh.re/', 10),
#  ('https://censuurvrij.com/', 10),
#  ('https://www.dlmplus.nl/', 10),
#  ('https://inspanje.nl/', 10),
#  ('https://www.vox.com/', 10),
#  ('https://www.secutips.nl/', 10),
#  ('https://www.volleybalkrant.nl/', 10),
#  ('https://www.levgroothandel.nl/', 10),
#  ('http://www.meternieuws.nl/', 10),
#  ('https://www.bouwendnederland.nl/', 10),
#  ('https://www.politico.eu/', 10),
#  ('https://www.apache.be/', 10),
#  ('http://www.koksijde.be/', 10),
#  ('https://www.voetbalprimeur.be/', 10),
#  ('https://www.denhaag.nl/', 10),
#  ('https://www.theverge.com/', 9),
#  ('https://techpulse.be/', 9),
#  ('http://nporadio1.nl/', 9),
#  ('https://www.argumentenfabriek.nl/', 9),
#  ('http://thuisarts.nl', 9),
#  ('http://wel.nl', 9),
#  ('https://sliedrecht24.nl/', 9),
#  ('https://www.maggiedeblock.be/', 9),
#  ('http://www.igo.nl/', 9),
#  ('https://moien.lu/', 9),
#  ('https://www.despecialist.eu/', 9),
#  ('https://sleutelstad.nl/', 9),
#  ('https://www.mariabode.nl/', 9),
#  ('http://overhetcoronavirus.nl', 9),
#  ('https://www.zwollenu.nl/', 9),
#  ('https://www.infinance.nl/', 9),
#  ('https://www.gooieneemlander.nl/', 9),
#  ('https://mobile.twitter.com/', 9),
#  ('https://vvte.nu/', 9),
#  ('https://digitalekrant.volkskrant.nl/', 9),
#  ('http://voorbeterov.nl/', 9),
#  ('https://www.agoria.be/', 9),
#  ('https://www.autogids.be/', 9),
#  ('https://www.reanimatieraad.nl/', 9),
#  ('http://www.tref.eu/', 9),
#  ('https://m.limburger.nl/', 9),
#  ('https://debatdirect.tweedekamer.nl/', 9),
#  ('https://www.redactie24.be/', 9),
#  ('http://atv.be/', 9),
#  ('https://slimbeleggen.com/', 9),
#  ('https://www.linkmagazine.nl/', 9),
#  ('https://www.accountancyvanmorgen.nl/', 9),
#  ('https://a.msn.com/', 9),
#  ('http://pltwps.it/', 9),
#  ('https://go.uva.nl/', 9),
#  ('http://www.technischwerken.nl/', 9),
#  ('https://www.fr-fans.nl/', 9),
#  ('https://business.techpulse.be/', 9),
#  ('https://www.nzherald.co.nz/', 9),
#  ('https://www.longfonds.nl/', 9),
#  ('https://www.managersonline.nl/', 9),
#  ('https://www.alaraby.co.uk/', 9),
#  ('https://112midden-groningen.nl/', 9),
#  ('https://corona-scanner.com/', 9),
#  ('https://www.magicontheweb.com/', 9),
#  ('https://herstelderepubliek.wordpress.com/', 9),
#  ('https://video.corriere.it/', 9),
#  ('https://denhelderactueel.nl/', 9),
#  ('https://www.eemskrant.nl/', 9),
#  ('http://www.rainews.it/', 9),
#  ('https://www.vilans.nl/', 9),
#  ('https://m.hbvl.be/', 9),
#  ('http://www.israelnationalnews.com/', 9),
#  ('https://zultewaregemrss.be/', 9),
#  ('https://standardluikrss.be/', 9),
#  ('https://www.niburu.co/', 9),
#  ('https://www.radioreflex.be/', 9),
#  ('https://nl.mashable.com/', 9),
#  ('http://VoetbalPrimeur.be', 9),
#  ('http://www.beatfm.nl/', 9),
#  ('https://www.psvfans.nl/', 9),
#  ('https://www.rtvfocuszwolle.nl/', 9),
#  ('https://www.ggdnog.nl/', 9),
#  ('http://www.peelenmaasvenray.nl/', 9),
#  ('https://www.demeerpeen.nl/', 9),
#  ('https://www.nieuwsonline.nu/', 9),
#  ('https://rtva.nl/', 9),
#  ('https://www.adfiz.nl/', 9),
#  ('https://mediamagazine.nl/', 9),
#  ('https://top10lijst.com/', 9),
#  ('https://www.sciencemag.org/', 8),
#  ('https://www.hogeschoolrotterdam.nl/', 8),
#  ('https://www.kvk.nl/', 8),
#  ('https://rtvkontakt.nl/', 8),
#  ('http://Akkerwijzer.nl', 8),
#  ('https://www.ggdhaaglanden.nl/', 8),
#  ('https://www.bloglovin.com/', 8),
#  ('https://dordtcentraal.nl/', 8),
#  ('https://ggdhm.nl/', 8),
#  ('https://www.houten.nl/', 8),
#  ('https://scholendicht.petities.nl', 8),
#  ('https://www.elsevierweekblad.nl/', 8),
#  ('https://info-over-kanker.nl/', 8),
#  ('https://www.dub.uu.nl/', 8),
#  ('https://www.vr-press.nl/', 8),
#  ('http://www.viln.be/', 8),
#  ('http://GPUpdate.net', 8),
#  ('https://acerta.ambsdr.io/', 8),
#  ('https://www.vastgoedmarkt.nl/', 8),
#  ('https://www.advalvas.vu.nl/', 8),
#  ('http://tiny.cc/', 8),
#  ('https://www.jeroenboschziekenhuis.nl/', 8),
#  ('https://www.manners.nl/', 8),
#  ('http://dutchtaxicompany.com', 8),
#  ('https://nextstrain.org/', 8),
#  ('https://www.rendement.nl/', 8),
#  ('https://www.nejm.org/', 8),
#  ('http://www.naardernieuws.nl/', 8),
#  ('https://www.rodekruis.be/', 8),
#  ('http://RD.nl', 8),
#  ('http://rivm.nl/', 8),
#  ('https://www.cpb.nl/', 8),
#  ('https://www.wsj.com/', 8),
#  ('https://fashionunited.be/', 8),
#  ('https://www.thesun.co.uk/', 8),
#  ('https://nijkerk.nieuws.nl/', 8),
#  ('http://WielerFlits.nl', 8),
#  ('https://www.faz.net/', 8),
#  ('https://www.ajaxfanatics.nl/', 8),
#  ('https://www.europarl.europa.eu/', 8),
#  ('http://FamilieNieuws.com', 8),
#  ('https://www.tln.nl/', 8),
#  ('https://www.olvg.nl/', 8),
#  ('https://www.wintersport.nl/', 8),
#  ('https://www.ajaxshowtime.com/', 8),
#  ('https://loom.ly/', 8),
#  ('https://hockey.nl/', 8),
#  ('https://www.slideshare.net/', 8),
#  ('https://weekend.knack.be/', 8),
#  ('https://www.npo3fm.nl/', 8),
#  ('http://link.marktplaats.nl/', 8),
#  ('https://www.snowrepublic.nl/', 8),
#  ('https://www.persberichten.com/', 8),
#  ('https://youtube.com/', 8),
#  ('https://www.036almere.nl/', 8),
#  ('https://www.ftm.nl/', 8),
#  ('http://FR-Fans.nl', 8),
#  ('https://www.twentefans.nl/', 8),
#  ('http://ctlk.nl/', 8),
#  ('https://www.nevobo.nl/', 8),
#  ('https://omroephorstaandemaas.nl/', 8),
#  ('https://www.rtl.nl/', 8),
#  ('https://elpais.com/', 8),
#  ('https://stichtingvaccinvrij.nl/', 8),
#  ('https://www.totaaltv.nl/', 8),
#  ('https://emmercourant.nl/', 8),
#  ('http://www.waterwegsport.nl/', 8),
#  ('http://www.foodholland.nl/', 8),
#  ('http://NOS.nl', 8),
#  ('https://www.waldnet.nl/', 8),
#  ('https://horst24.nl/', 8),
#  ('https://facebook.com/', 8),
#  ('http://klmf.ly/', 8),
#  ('https://www.politie.be/', 8),
#  ('http://sint-pieters-leeuw.eu/', 8),
#  ('https://www.112wagenborgen.eu/', 8),
#  ('https://andijkernieuws.net/', 8),
#  ('http://www.agriholland.nl/', 8),
#  ('https://1rs.nl/', 8),
#  ('https://www.spreekbuis.nl/', 8),
#  ('https://meesters-belastingconsulenten.be/', 8),
#  ('https://www.belastingdienst.nl/', 8),
#  ('https://www.lto.nl/', 8),
#  ('https://www.dumpert.nl/', 8),
#  ('https://www.racesport.nl/', 7),
#  ('https://hoogeveenschecourant.nl/', 7),
#  ('https://coevordernieuws.nl/', 7),
#  ('https://nieuwsemmen.com/', 7),
#  ('https://www.ilfattoquotidiano.it/', 7),
#  ('http://www.israeltoday.nl/', 7),
#  ('https://www.fonds-antizyklik-sjb.de/', 7),
#  ('https://www.thailandblog.nl/', 7),
#  ('https://www.politico.com/', 7),
#  ('https://ibop.nl/', 7),
#  ('https://www.vrijspreker.nl/', 7),
#  ('https://www.hollywoodreporter.com/', 7),
#  ('https://groningerkrant.nl/', 7),
#  ('https://www.gamekings.tv/', 7),
#  ('https://112nieuws.net/', 7),
#  ('https://news-groningen.blogspot.com/', 7),
#  ('http://www.vrzl.nl', 7),
#  ('https://www.computable.be/', 7),
#  ('https://www.peelbelangonline.nl/', 7),
#  ('https://www.installatie.nl/', 7),
#  ('http://www.ggdlimburgnoord.nl', 7),
#  ('https://www.wanttoknow.nl/', 7),
#  ('https://www.japantimes.co.jp/', 7),
#  ('https://sz.de/', 7),
#  ('https://y.is/', 7),
#  ('http://www.hetkrantje-online.nl/', 7),
#  ('https://gridtalk.nl/', 7),
#  ('https://www.thelocal.it/', 7),
#  ('https://goudafm.nl/', 7),
#  ('http://www.diemernieuws.nl/', 7),
#  ('http://WOS.nl', 7),
#  ('http://www.tagesschau.de/', 7),
#  ('https://www.artsenkrant.com/', 7),
#  ('https://dutchitchannel.nl/', 7),
#  ('https://lci.rivm.nl/', 7),
#  ('https://www.perssupport.nl/', 7),
#  ('http://NDR.de', 7),
#  ('https://leukinformatief.blogspot.com/', 7),
#  ('https://www.knltb.nl/', 7),
#  ('https://www.events.nl/', 7),
#  ('https://www.pen.nl/', 7),
#  ('https://www.n-tv.de/', 7),
#  ('https://omroepflevoland.nl/', 7),
#  ('http://tl.gd/', 7),
#  ('http://www.wilbertoordonline.nl/', 7),
#  ('https://www.filmtotaal.nl/', 7),
#  ('http://www.merwetv.nl/', 7),
#  ('https://www.ggdru.nl/', 7),
#  ('https://dmgdeurne.nl/', 7),
#  ('https://www.jouregio.nl/', 7),
#  ('https://www.vrouwenvoetbalnieuws.nl/', 7),
#  ('https://www.mirror.co.uk/', 7),
#  ('https://onderzoekers.nl/', 7),
#  ('https://laboratorium.nl/', 7),
#  ('https://www.hoevrouwendenken.nl/', 7),
#  ('https://www.utrechtfans.nl/', 7),
#  ('http://www.mooisonenbreugel.nl/', 7),
#  ('https://www.goudstandaard.com/', 7),
#  ('http://BD.nl', 7),
#  ('https://www.bfmtv.com/', 7),
#  ('https://vm.tiktok.com/', 7),
#  ('https://www.latimes.com/', 7),
#  ('https://www.ikbenzwanger.com/', 7),
#  ('https://www.leidschdagblad.nl/', 7),
#  ('https://www.ntvg.nl/', 7),
#  ('https://tmblr.co/', 7),
#  ('https://www.heeze24.nl/', 7),
#  ('https://stubru.be/', 7),
#  ('https://en.unesco.org/', 7),
#  ('https://www.awvn.nl/', 7),
#  ('https://sportingcharleroirss.be/', 7),
#  ('https://fashionunited.nl/', 7),
#  ('http://Vrt.be/', 7),
#  ('https://www.blikopnoordwijk.nl/', 7),
#  ('https://www.nature.com/', 7),
#  ('https://www.rtvlove.nl/', 7),
#  ('https://www.rawepo.be/', 7),
#  ('https://www.tilburgers.nl/', 7),
#  ('https://www.techzine.be/', 7),
#  ('https://www.nieuwsbladtransport.nl/', 7),
#  ('https://www.liwwadders.nl/', 7),
#  ('https://nieuwsbladdekaap.nl/', 7),
#  ('https://www.dr.dk/', 7),
#  ('https://www.osb.nl/', 7),
#  ('https://www.schaatsen.nl/', 7),
#  ('http://bndestem.nl', 7),
#  ('https://tennisplaza.be/', 7),
#  ('https://www.fcgfans.nl/', 7),
#  ('https://www.prinsenbeeknieuws.nl/', 7),
#  ('http://www.youtube.com/', 7),
#  ('http://Nieuws.nl', 7),
#  ('https://video.foxnews.com/', 7),
#  ('https://www.nctv.nl/', 7),
#  ('https://gouweijsselnieuws.nl/', 7),
#  ('https://nl.godfootsteps.org/', 7),
#  ('https://www.coronavirusupdate.nl/', 7),
#  ('https://www.noordernieuws.be/', 7),
#  ('https://forumvoordemocratie.nl/', 7),
#  ('https://www.bollenstreekomroep.nl/', 7),
#  ('https://nieuwsvanmorgen.nl/', 7),
#  ('https://goeree-overflakkee.nieuws.nl/', 7),
#  ('https://www.beout.be/', 7),
#  ('https://groenlinks.nl/', 7),
#  ('https://www.grandprixradio.nl/', 7),
#  ('https://duitslandinstituut.nl/', 7),
#  ('https://nvic.nl/', 7),
#  ('https://www.bisdomdenbosch.nl/', 7),
#  ('https://winsum.nieuws.nl/', 7),
#  ('http://goo.gl/', 7),
#  ('https://www.autoweek.nl/', 7),
#  ('https://festileaks.com/', 7),
#  ('https://rfrk.nl/', 7),
#  ('https://www.werkenbijkinderopvang.nl/', 7),
#  ('https://henkbaron.nl/', 7),
#  ('https://www.voetbal24.be/', 7),
#  ('https://www.missienederland.nl/', 7),
#  ('https://zoetermeer.nieuws.nl/', 7),
#  ('https://www.vrbn.nl/', 7),
#  ('https://www.zhzveilig.nl/', 7),
#  ('https://ondernemersplein.kvk.nl/', 7),
#  ('http://FVD.nl/', 7),
#  ('https://www.nza.nl/', 7),
#  ('https://tvvisie.nl/', 7),
#  ('https://www.rijswijk.nl/', 7),
#  ('http://bitly.com/', 7),
#  ('https://almere.nl/', 7),
#  ('https://www.techpulse.be/', 7),
#  ('https://www.medicalfacts.nl/', 6),
#  ('http://motornieu.ws/', 6),
#  ('https://trendsworld.net/', 6),
#  ('https://www.vpro.nl/', 6),
#  ('https://www.agri24.nu/', 6),
#  ('http://forum.3keernix.nl/', 6),
#  ('https://www.cyclingopinions.nl/', 6),
#  ('http://news.sky.com/', 6),
#  ('https://www.zorgneticuro.be/', 6),
#  ('https://www.maxvandaag.nl/', 6),
#  ('https://www.forbes.com/', 6),
#  ('https://podplayer.net/', 6),
#  ('https://www.universiteitleiden.nl/', 6),
#  ('https://rtvbodegraven.nl/', 6),
#  ('https://nos.nl', 6),
#  ('http://www.repentnetherlands.nl/', 6),
#  ('http://HLN.be', 6),
#  ('https://www.regioonline.nl/', 6),
#  ('http://LC.nl', 6),
#  ('https://theoptimist.nl/', 6),
#  ('https://oor.nl/', 6),
#  ('https://www.regionoordkop.nl/', 6),
#  ('https://t.co/', 6),
#  ('https://www.vvponline.nl/', 6),
#  ('https://local.google.com/', 6),
#  ('https://www.rtvmaastricht.nl/', 6),
#  ('https://nieuws.btcdirect.eu/', 6),
#  ('https://www.nhg.org/', 6),
#  ('https://metro.co.uk/', 6),
#  ('https://www.hivvereniging.nl/', 6),
#  ('https://www.ijsselmondenieuws.nl/', 6),
#  ('https://theconversation.com/', 6),
#  ('https://www.mediacourant.nl/', 6),
#  ('http://Wel.nl', 6),
#  ('https://paper.li/', 6),
#  ('https://www.zutphennieuws.nl/', 6),
#  ('https://www.express.co.uk/', 6),
#  ('https://gezinsbode.nl/', 6),
#  ('https://puuropreis.nl/', 6),
#  ('http://www.voorne-putten.nl/', 6),
#  ('http://www.grootnissewaard.nl/', 6),
#  ('https://www.klantcontact.nl/', 6),
#  ('https://www.tagesschau.de/', 6),
#  ('http://www.muidernieuws.nl/', 6),
#  ('https://www.deventerrtv.nl/', 6),
#  ('https://www.flows.be/', 6),
#  ('https://www.superguide.nl/', 6),
#  ('https://www.pigbusiness.nl/', 6),
#  ('https://embed.scribblelive.com/', 6),
#  ('http://www.salland747.nl/', 6),
#  ('https://www.sallandtv.nl/', 6),
#  ('https://wielerrevue.nl/', 6),
#  ('https://zorgen.nl/', 6),
#  ('https://s.pu.nl/', 6),
#  ('https://www.marketingtribune.nl/', 6),
#  ('http://Voetbalkrant.com', 6),
#  ('https://www.missethoreca.nl/', 6),
#  ('https://www.defryskemarren.nl/', 6),
#  ('https://www.brainwash.nl/', 6),
#  ('https://www.autosportkrant.be/', 6),
#  ('http://dedrontenaar.nl/', 6),
#  ('http://telegraaf.nl/', 6),
#  ('https://www.news.com.au/', 6),
#  ('https://www.umcg.nl/', 6),
#  ('https://www.globaltimes.cn/', 6),
#  ('https://www.fontys.nl/', 6),
#  ('https://www.npr.org/', 6),
#  ('https://www.humanpowernow.com/', 6),
#  ('https://oisterwijk.nl/', 6),
#  ('https://www.gemertsnieuwsblad.nl/', 6),
#  ('https://www.rug.nl/', 6),
#  ('https://www.stedendriehoek.nl/', 6),
#  ('https://nieuws365.be/', 6),
#  ('https://www.pokercity.nl/', 6),
#  ('https://www.ecdc.europa.eu/', 6),
#  ('https://jamanetwork.com/', 6),
#  ('https://www.1almere.nl/', 6),
#  ('https://time.com/', 6),
#  ('http://www.almeredezeweek.nl/', 6),
#  ('http://www.almere-nieuws.nl/', 6),
#  ('http://Nederlandwereldwijd.nl', 6),
#  ('https://www.nieuws365.be/', 6),
#  ('https://radioisrael.nl/', 6),
#  ('https://www.newsweek.com/', 6)]

# %% [markdown]
# ###
